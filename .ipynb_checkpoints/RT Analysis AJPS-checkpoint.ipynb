# %%
from AJPS_full import keygen, enc, dec
from util import timer, int2string, string2int
import matplotlib.pyplot as plt
import numpy as np
from ecc import E, D
# %matplotlib inline

# %%
ns = [11213, 19937, 21701, 23209, 44497, 86243, 110503, 132049, 216091, 756839, 859433, 1257787,
     1398269, 2976221, 3021377, 6972593, 13446917] 
#       20996011, 24036583, 25964951, 30402457, 32582657,
#      37156667, 43112609, 42643801, 57885161, 74207281, 77232917, 82589933]

# %% [markdown]
# AJPS FULL without GMPY2

# %%
h = 256
runs = 2
rho = 256

acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = string2int("Robert DeNiro thinks that Trump will go for a third term via a war")

for i, n in enumerate(ns):
    
    p = 2**n-1

    # KEYGEN
    params = [n, h]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk, _ = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, p]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m
# Out:
# 11213 0.18384528160095215
# 19937 0.31042778491973877
# 21701 0.3370788097381592
# 23209 0.33537447452545166
# 44497 0.6400866508483887
# 86243 1.2225446701049805
# 110503 1.583648443222046
# 132049 1.9230867624282837
# 216091 3.2596561908721924
# 756839 15.746907114982605
# 859433 15.038305044174194
# 1257787 22.51357865333557
# 1398269 28.391827702522278
# 2976221 63.92268085479736
# 3021377 70.58811807632446
# 6972593 141.02528262138367
# 13446917 266.0319777727127

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])

# %% [markdown]
# AJPS bit-by-bit without GMPY2

# %%
from AJPS_basic import keygen, enc, dec

# %%
h = 256
runs = 2
rho = 256

acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = 0

for i, n in enumerate(ns):
    
    p = 2**n-1

    # KEYGEN
    params = [n, h]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C, signed = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, n, h, signed]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m
# Out:
# 11213 0.004098653793334961
# 19937 0.002877950668334961
# 21701 0.0028220415115356445
# 23209 0.0026401281356811523
# 44497 0.00289309024810791
# 86243 0.0025374889373779297
# 110503 0.0030421018600463867
# 132049 0.0027579069137573242
# 216091 0.002945423126220703
# 756839 0.005930662155151367
# 859433 0.0033599138259887695
# 1257787 0.010784268379211426
# 1398269 0.00881946086883545
# 2976221 0.014299392700195312
# 3021377 0.009769916534423828
# 6972593 0.5266731977462769
# 13446917 0.8724544048309326

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])

# %% [markdown]
# AJPS FULL BPL without GYMP2:

# %%
from AJPS_full_bpl import keygen, enc, dec

# %%
h = 256
runs = 2
rho = 256

acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = string2int("Robert DeNiro thinks that Trump will go for a third term via a war")

for i, n in enumerate(ns):
    
    p = 2**n-1

    # KEYGEN
    params = [n, h, p, False]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk, _ = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h, rho]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, p]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m
# Out:
# 11213 0.0074738264083862305
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-237c94c6aa3f> in <module>
#      28     # DECRYPTION
#      29     params = [C, sk, p]
# ---> 30     time, ret = timer(dec, params, runs)
#      31     acc[i][2] = time
#      32     m_prime = ret
#
# ~/projects/COT6930_2/util.py in timer(fx, params, runs)
#      22     for _ in range(runs):
#      23         before = time.time()
# ---> 24         ret = fx(*params)
#      25         after = time.time()
#      26
#
# ~/projects/COT6930_2/AJPS_full_bpl.py in dec(C, sk, pp)
#     123
#     124 def dec(C, sk, pp):
# --> 125     (C1, C2) = C
#     126     bplF = sk
#     127     C2_star = int_times_bpl(C1, bplF)
#
# TypeError: cannot unpack non-iterable int object

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5954e3f002ef> in <module>
# ----> 1 plt.figure(figsize=(10,7))
#       2 ax = plt.subplot(131)
#       3 ax.set(title="keygen")
#       4 _ = plt.plot(ns, acc[:, 0])
#       5 ax = plt.subplot(132, sharey=ax)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# AJPS FULL with GMPY2

# %%
from gimpy import mpz
from AJPS_full import keygen, enc, dec

# %%
h = mpz(256)
runs = 2
rho = 256


acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = string2int("Robert DeNiro thinks that Trump will go for a third term via a war")

for i, mpz(n) in enumerate(ns):

    
    p = mpz(2**n-1)

    # KEYGEN
    params = [n, h]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk, _ = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, p]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])

# %% [markdown]
# AJPS basic with GMPY2

# %%
from AJPS_basic import keygen, enc, dec

# %%
h = mpz(256)
runs = 2
rho = 256

acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = 0

for i, mpz(n) in enumerate(ns):
    
    p = mpz(2**n-1)

    # KEYGEN
    params = [n, h]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C, signed = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, n, h, signed]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])

# %% [markdown]
# AJPS FULL BPL with GMPY2

# %%
from AJPS_full_bpl import keygen, enc, dec
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1ba55d89ddab> in <module>
# ----> 1 from AJPS_full_bpl import keygen, enc, dec
#
# ~/projects/COT6930_2/AJPS_full_bpl.py in <module>
#      24
#      25
# ---> 26 def int_times_bpl(a, bpl, pp = p):
#      27     bpl.sort()
#      28     acc = 0
#
# NameError: name 'p' is not defined

# %%
h = mpz(256)
runs = 2
rho = 256

acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = string2int("Robert DeNiro thinks that Trump will go for a third term via a war")

for i, mpz(n) in enumerate(ns):
    
    p = mpz(2**n-1)

    # KEYGEN
    params = [n, h, p, True]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk, _ = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C, signed = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, p]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])

# %%
from AJPS_full import keygen, enc, dec
from util import timer, int2string, string2int
import matplotlib.pyplot as plt
import numpy as np
from ecc import E, D

# %%
ns = [11213, 19937, 21701, 23209, 44497, 86243, 110503, 132049, 216091, 756839, 859433, 1257787,
     1398269, 2976221, 3021377, 6972593, 13446917] 
#       20996011, 24036583, 25964951, 30402457, 32582657,
#      37156667, 43112609, 42643801, 57885161, 74207281, 77232917, 82589933]

# %%
h = 256
runs = 2
rho = 256

acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = string2int("Robert DeNiro thinks that Trump will go for a third term via a war")

for i, n in enumerate(ns):
    
    p = 2**n-1

    # KEYGEN
    params = [n, h]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk, _ = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, p]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m
# Out:
# 11213 0.16744768619537354
# 19937 0.3045917749404907
# 21701 0.32477760314941406
# 23209 0.3489847183227539
# 44497 0.6421362161636353
# 86243 1.1732392311096191
# 110503 1.505086898803711
# 132049 1.7945598363876343
# 216091 2.9498945474624634
# 756839 11.942893266677856
# 859433 12.741227507591248
# 1257787 19.54835867881775
# 1398269 21.414480209350586
# 2976221 46.92730402946472
# 3021377 47.612627387046814
# 6972593 117.49855291843414
# 13446917 282.3331552743912

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])

# %%
correctness
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
from AJPS_basic import keygen, enc, dec

# %%
h = 256
runs = 2
rho = 256

acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = string2int("Robert DeNiro thinks that Trump will go for a third term via a war")

for i, n in enumerate(ns):
    
    p = 2^n-1

    # KEYGEN
    params = [n, h]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk, _ = ret
    
    # ENCRYPTION
    params = [m, pk, n, h, p]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, 2^n-1]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m

# %%
h = 256
runs = 100
fx = enc
rho = 256

acc = []

m = string2int("Robert DeNiro thinks that Trump will go for a third term via a war")

for n in ns:
    
    pk, sk, _ = keygen(n, h)
    params = [m, pk, n, h]
    
    time, ret = timer(fx, params, runs)
    acc.append(time)

_ = plt.plot(ns, acc)

# %%
h = 256
runs = 100
fx = dec
rho = 256

acc = []

m = "Robert DeNiro thinks that Trump will go for a third term via a war"
m = string2int(m)
for n in ns:
    
    params = [m, pk, n, h]
    
    time, ret = timer(fx, params, runs)
    acc.append(time)

_ = plt.plot(ns, acc)

# %%
h = 256
runs = 100
fx = 
rho = 256

acc = []

m = "Robert DeNiro thinks that Trump will go for a third term via a war"
m = string2int(m)
for n in ns:
    params = [m, pk, n, h]
    
    time, ret = timer(fx, params, runs)
    acc.append(time)
    

_ = plt.plot(ns, acc)

# %%
n = 756839
h = 256
p = 2**n-1
lam = h
rho = 256 # The number of repetitions of a bit


pk, sk, g = keygen(n, h)

# %%
R, T = pk


C1 = R
C2 = -1

C = (C1,C2)

mlen = n // rho

m = 2**mlen-1

# %%
C = (C1, C2 ^ E(m, rho))

# %%
print(dec(C, sk, 2**n-1))

# %%
sk

# %%
from AJPS_full import keygen, enc, dec
from util import timer, int2string, string2int
import matplotlib.pyplot as plt
import numpy as np
from ecc import E, D
# %matplotlib inline

# %%
ns = [11213, 19937, 21701, 23209, 44497, 86243, 110503, 132049, 216091, 756839, 859433, 1257787,
     1398269, 2976221, 3021377, 6972593, 13446917] 
#       20996011, 24036583, 25964951, 30402457, 32582657,
#      37156667, 43112609, 42643801, 57885161, 74207281, 77232917, 82589933]

# %% [markdown]
# AJPS FULL without GMPY2

# %%
h = 256
runs = 2
rho = 256

acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = string2int("Robert DeNiro thinks that Trump will go for a third term via a war")

for i, n in enumerate(ns):
    
    p = 2**n-1

    # KEYGEN
    params = [n, h]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk, _ = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, p]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m
# Out:
# 11213 0.1417076587677002
# 19937 0.24902546405792236
# 21701 0.2602345943450928
# 23209 0.27582108974456787
# 44497 0.5234375
# 86243 0.998267412185669
# 110503 1.286623477935791

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])

# %% [markdown]
# AJPS bit-by-bit without GMPY2

# %%
from AJPS_basic import keygen, enc, dec

# %%
h = 256
runs = 2
rho = 256

acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = 0

for i, n in enumerate(ns):
    
    p = 2**n-1

    # KEYGEN
    params = [n, h]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C, signed = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, n, h, signed]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m
# Out:
# 11213 0.0023306608200073242
# 19937 0.0020731687545776367
# 21701 0.0020617246627807617
# 23209 0.0020829439163208008
# 44497 0.0021452903747558594
# 86243 0.0022096633911132812
# 110503 0.0021570920944213867

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])

# %% [markdown]
# AJPS FULL BPL without GYMP2:

# %%
from AJPS_full_bpl import keygen, enc, dec

# %%
h = 256
runs = 2
rho = 256

acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = string2int("Robert DeNiro thinks that Trump will go for a third term via a war")

for i, n in enumerate(ns):
    
    p = 2**n-1

    # KEYGEN
    params = [n, h, p, False]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk, _ = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h, rho]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, p, rho]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m
# Out:
# 11213 0.005244731903076172
# 19937 0.0076656341552734375
# 21701 0.007609844207763672
# 23209 0.008078575134277344
# 44497 0.016113996505737305
# 86243 0.038301825523376465
# 110503 0.056218624114990234

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])

# %% [markdown]
# AJPS FULL with GMPY2

# %%
from gmpy2 import mpz
from AJPS_full import keygen, enc, dec

# %%
h = mpz(256)
runs = 2
rho = 256


acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = string2int("Robert DeNiro thinks that Trump will go for a third term via a war")

for i, n in enumerate(ns):
    
    n = mpz(n)
    p = mpz(2**n-1)

    # KEYGEN
    params = [n, h]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk, _ = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, p]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m
# Out:
# 11213 0.1471315622329712
# 19937 0.25485682487487793
# 21701 0.2755460739135742
# 23209 0.29390597343444824
# 44497 0.5885022878646851
# 86243 1.1067978143692017
# 110503 1.4066762924194336

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])

# %% [markdown]
# AJPS basic with GMPY2

# %%
from AJPS_basic import keygen, enc, dec

# %%
h = mpz(256)
runs = 2
rho = 256

acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = 0

for i, n in enumerate(ns):
    
    n = mpz(n)
    p = mpz(2**n-1)

    # KEYGEN
    params = [n, h]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C, signed = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, n, h, signed]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m
# Out:
# 11213 0.002884984016418457
# 19937 0.002224564552307129
# 21701 0.002615690231323242
# 23209 0.0021666288375854492
# 44497 0.0022101402282714844
# 86243 0.002239227294921875
# 110503 0.0022313594818115234

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])

# %% [markdown]
# AJPS FULL BPL with GMPY2

# %%
from AJPS_full_bpl import keygen, enc, dec

# %%
h = mpz(256)
runs = 2
rho = 256

acc = np.zeros((len(ns), 3))
correctness = np.zeros(len(ns), dtype=bool)

m = string2int("Robert DeNiro thinks that Trump will go for a third term via a war")

for i, n in enumerate(ns):
    
    n = mpz(n)
    p = mpz(2**n-1)

    # KEYGEN
    params = [n, h, p, True]
    time, ret = timer(keygen, params, runs)
    acc[i][0] = time
    pk, sk, _ = ret
    
    # ENCRYPTION
    params = [m, pk, p, n, h, rho]
    time, ret = timer(enc, params, runs)
    acc[i][1] = time
    C = ret
    
    print(n, time)
    
    # DECRYPTION
    params = [C, sk, p, rho]
    time, ret = timer(dec, params, runs)
    acc[i][2] = time
    m_prime = ret
    
    # SUCCESS?
    correctness[i] = m_prime == m
# Out:
# 11213 0.005023956298828125
# 19937 0.004989266395568848
# 21701 0.004711508750915527
# 23209 0.004464268684387207
# 44497 0.0066471099853515625
# 86243 0.012082219123840332
# 110503 0.015603423118591309

# %%
plt.figure(figsize=(10,7))
ax = plt.subplot(131)
ax.set(title="keygen")
_ = plt.plot(ns, acc[:, 0])
ax = plt.subplot(132, sharey=ax)
ax.set(title="encryption")
_ = plt.plot(ns, acc[:, 1])
ax = plt.subplot(133, sharey=ax)
ax.set(title="decryption")
_ = plt.plot(ns, acc[:, 2])
